# %%
import pandas as pd
x = pd.read_csv('/Users/huongnguyen/Downloads/age.csv')
print (x[:39])
# Out:
#       Age     Gender Total      F_Freq_%
# 0   15-20     Female     2  0.7333333333
# 1   15-20     Female     3             1
# 2   15-20     Female     1           0.4
# 3   15-20     Female     1  0.6666666667
# 4     >25     Female     1  0.4666666667
# 5     >25     Female     1  0.4666666667
# 6   15-20     Female     1  0.6666666667
# 7     >25     Female     1  0.2666666667
# 8   15-20     Female     2           0.8
# 9   15-20     Female     2  0.7333333333
# 10  15-20     Female     1  0.4666666667
# 11  15-20       Male     1           0.6
# 12  15-20       Male     1  0.4666666667
# 13  15-20       Male     1  0.7333333333
# 14  15-20       Male     3  0.6666666667
# 15  20-25     Female     2           0.6
# 16  15-20       Male     2           0.8
# 17  15-20     Female     1  0.6666666667
# 18  15-20     Female     1  0.5333333333
# 19  15-20     Female     1           0.6
# 20  15-20     Female     1  0.5333333333
# 21  15-20     Female     2  0.5333333333
# ...

# %%
import pandas as pd
x = pd.read_csv('/Users/huongnguyen/Downloads/altruism.csv')
print (x[:39])
# Out:
#       Age     Gender Total Freq._use F_Freq_% APS1 APS2 APS3 APS4 F_APS  \
# 0   15-20     Female     2         4   26.67%    4    4    5    1    14
# 1   15-20     Female     3         5   33.33%    5    3    1    5    14
# 2   15-20     Female     1         2   13.33%    1    1    2    1     5
# 3   15-20     Female     1         5   33.33%    1    3    1    4     9
# 4     >25     Female     1         5   33.33%    5    5    4    3    17
# 5     >25     Female     1         5   33.33%    5    5    4    3    17
# 6   15-20     Female     1         5   33.33%    2    2    4    3    11
# 7     >25     Female     1         1    6.67%    3    1    1    1     6
# 8   15-20     Female     2         5   33.33%    5    5    5    5    20
# 9   15-20     Female     2         5   33.33%    2    2    1  NaN     5
# 10  15-20     Female     1         4   26.67%    1    5    3    5    14
# 11  15-20       Male     1         4   26.67%    5    5    3    4    17
# ...

# %%
import pandas as pd
col_list=["Freq._use", "F_APS"]
x = pd.read_csv('/Users/huongnguyen/Downloads/altruism.csv', usecols=col_list)

y=(df["Freq._use"])
print (y[:39])
# Out:
# 0     4
# 1     5
# 2     2
# 3     5
# 4     5
# 5     5
# 6     5
# 7     1
# 8     5
# 9     5
# 10    4
# 11    4
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    4
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    5
# 28    5
# 29    5
# 30    4
# 31    5
# 32    5
# 33    5
# 34    5
# 35    5
# 36    2
# 37    5
# 38    1
# Name: Freq._use, dtype: object

# %%
import pandas as pd
col_list=["Freq._use", "F_APS"]
x = pd.read_csv('/Users/huongnguyen/Downloads/altruism.csv', usecols=col_list)

y=(df["Freq._use"])
print (y[:39])
z=(df["F_APS"])
print (z[:39])
# Out:
# 0     4
# 1     5
# 2     2
# 3     5
# 4     5
# 5     5
# 6     5
# 7     1
# 8     5
# 9     5
# 10    4
# 11    4
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    4
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    5
# 28    5
# 29    5
# 30    4
# 31    5
# 32    5
# 33    5
# 34    5
# 35    5
# 36    2
# 37    5
# 38    1
# Name: Freq._use, dtype: object
# 0     14
# 1     14
# 2      5
# 3      9
# 4     17
# 5     17
# 6     11
# 7      6
# 8     20
# 9      5
# 10    14
# 11    17
# 12    10
# 13     8
# 14     6
# 15    14
# 16     6
# 17    11
# 18    20
# 19    14
# 20    20
# 21    17
# 22    15
# 23     9
# 24     7
# 25     8
# 26     4
# 27    10
# 28    20
# 29    14
# 30     5
# 31    18
# 32     4
# 33    20
# 34    12
# 35    11
# 36    11
# 37    20
# 38    12
# Name: F_APS, dtype: object

# %%
import pandas as pd
col_list=["Freq._use", "F_APS"]
x = pd.read_csv('/Users/huongnguyen/Downloads/altruism.csv', usecols=col_list)
scale = {'Frequent Media Usage': ["Freq._use"],
        'Altruistic Personality Scale': ["F_APS"]
        }

df = pd.DataFrame(scale, columns = ['Frequent Media Usage', 'Altruistic Personality Scale'])

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df)
# Out:
#   Frequent Media Usage Altruistic Personality Scale
# 0            Freq._use                        F_APS

# %%
# include libraries

from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r'/Users/huongnguyen/Downloads/altruism.csv')

for key in data:
    print(key)
# Out:
# Age
# Gender
# Total
# Freq._use
# F_Freq_%
# APS1
# APS2
# APS3
# APS4
# F_APS
# F_APS_%
# P_VALUE

# %%
data_array = data['Age']
gender = data['Gender']
media = data['Total']
freq = data['Freq._use']
aptitude = data['F_APS']


print(data_array[:39])
print (gender[:39])

print(media[:39])
print(freq[:39])
print(aptitude[:39])
# Out:
# 0     15-20
# 1     15-20
# 2     15-20
# 3     15-20
# 4       >25
# 5       >25
# 6     15-20
# 7       >25
# 8     15-20
# 9     15-20
# 10    15-20
# 11    15-20
# 12    15-20
# 13    15-20
# 14    15-20
# 15    20-25
# 16    15-20
# 17    15-20
# 18    15-20
# 19    15-20
# 20    15-20
# 21    15-20
# 22    15-20
# 23    15-20
# 24    15-20
# 25    15-20
# 26    15-20
# 27    20-25
# 28    15-20
# 29    20-25
# 30    15-20
# 31    20-25
# 32    15-20
# 33    15-20
# 34    15-20
# 35    15-20
# 36    20-25
# 37    15-20
# 38    15-20
# Name: Age, dtype: object
# 0        Female
# 1        Female
# 2        Female
# 3        Female
# 4        Female
# 5        Female
# 6        Female
# 7        Female
# 8        Female
# 9        Female
# 10       Female
# 11         Male
# 12         Male
# 13         Male
# 14         Male
# 15       Female
# 16         Male
# 17       Female
# 18       Female
# 19       Female
# 20       Female
# 21       Female
# 22       Female
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886 entries, 0 to 885
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        40 non-null     object
#  1   Gender     40 non-null     object
#  2   Total      286 non-null    object
#  3   Freq._use  286 non-null    object
#  4   F_Freq_%   286 non-null    object
#  5   APS1       286 non-null    object
#  6   APS2       286 non-null    object
#  7   APS3       286 non-null    object
#  8   APS4       280 non-null    object
#  9   F_APS      286 non-null    object
# F_APS_%   286 non-null    object
#  11  P_VALUE    1 non-null      float64
# dtypes: float64(1), object(11)
# memory usage: 83.2+ KB

# %%
data.head()
# Out:
# F_APS_%  \
# 0  15-20  Female     2         4   26.67%    4    4    5    1    14   70.00%
# 1  15-20  Female     3         5   33.33%    5    3    1    5    14   70.00%
# 2  15-20  Female     1         2   13.33%    1    1    2    1     5   25.00%
# 3  15-20  Female     1         5   33.33%    1    3    1    4     9   45.00%
# 4    >25  Female     1         5   33.33%    5    5    4    3    17   85.00%
#
#         P_VALUE
# 0  2.699539e-09
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# importing pandas as pd 
import pandas as pd 
  
# Making data frame from the csv file 
df = pd.read_csv(r'/Users/huongnguyen/Downloads/altruism.csv') 
df[:39]
# Out:
#       Age     Gender Total Freq._use F_Freq_% APS1 APS2 APS3 APS4 F_APS  \
# 0   15-20     Female     2         4   26.67%    4    4    5    1    14
# 1   15-20     Female     3         5   33.33%    5    3    1    5    14
# 2   15-20     Female     1         2   13.33%    1    1    2    1     5
# 3   15-20     Female     1         5   33.33%    1    3    1    4     9
# 4     >25     Female     1         5   33.33%    5    5    4    3    17
# 5     >25     Female     1         5   33.33%    5    5    4    3    17
# 6   15-20     Female     1         5   33.33%    2    2    4    3    11
# 7     >25     Female     1         1    6.67%    3    1    1    1     6
# 8   15-20     Female     2         5   33.33%    5    5    5    5    20
# 9   15-20     Female     2         5   33.33%    2    2    1  NaN     5
# 10  15-20     Female     1         4   26.67%    1    5    3    5    14
# 11  15-20       Male     1         4   26.67%    5    5    3    4    17
# ...

# %%
df = pd.read_csv(r'/Users/huongnguyen/Downloads/altruism.csv')
ax1 = df.plot.scatter(x=df['Freq._use'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-0bfcfcb74151> in <module>
#       1 df = pd.read_csv(r'/Users/huongnguyen/Downloads/altruism.csv')
# ----> 2 ax1 = df.plot.scatter(x=df['Freq._use'])
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataframe = pd.read_csv(r"/Users/huongnguyen/Downloads/use.csv")
print(dataframe)
plt.show()
# Out:
#     Freq._use  F_APS
# 0        4.00  14.00
# 1        5.00  14.00
# 2        2.00   5.00
# 3        5.00   9.00
# 4        5.00  17.00
# ..        ...    ...
# 881      5.00  11.00
# 882      2.00  11.00
# 883      5.00  20.00
# 884      1.00  12.00
# 885      5.00   9.00
#
# [886 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataframe = pd.read_csv(r"/Users/huongnguyen/Downloads/use.csv")
print(dataframe)

dataframe.corr()
# Out:
#     Freq._use  F_APS
# 0        4.00  14.00
# 1        5.00  14.00
# 2        2.00   5.00
# 3        5.00   9.00
# 4        5.00  17.00
# ..        ...    ...
# 881      5.00  11.00
# 882      2.00  11.00
# 883      5.00  20.00
# 884      1.00  12.00
# 885      5.00   9.00
#
# [886 rows x 2 columns]
# Empty DataFrame
# Columns: []
# Index: []

# %%
dataframe.describe()
# Out:
#        Freq._use  F_APS
# count        286    286
# unique         5     15
# top         5.00  14.00
# freq         217     42

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataframe = pd.read_csv(r"/Users/huongnguyen/Downloads/use.csv")
dataframe_group = dataframe.groupby('Freq._use')

# %%
dataframe_group.size()
# Out:
# Freq._use
# 1.00          14
# 2.00          14
# 4.00          35
# 5.00         217
# Freq._use      6
# dtype: int64

# %%
APS_totals = dataframe_group.sum()
print(APS_totals)
# Out:
#                                                        F_APS
# Freq._use
# 1.00       6.0012.006.0012.006.0012.006.0012.006.0012.006...
# 2.00       5.0011.005.0011.005.0011.005.0011.005.0011.005...
# 4.00       14.0014.0017.0017.005.0014.0014.0017.0017.005....
# 5.00       14.009.0017.0017.0011.0020.005.0010.008.006.00...
# Freq._use                     F_APSF_APSF_APSF_APSF_APSF_APS

# %%
import pandas as pd
import numpy as np
dataframe = pd.read_csv(r"")
points=dataframe[:39] 
points.F_APS=pd.to_numeric(points.F_APS)

points.plot.scatter(x='Freq._use',y='F_APS')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
points.F_APS=pd.to_numeric(points.F_APS)
points.plot()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
points.F_APS=pd.to_numeric(points.F_APS)
points_csv = points.to_csv()

import numpy as np

points_array = np.array(points.values)


print(points_array)
# Out:
# [['4.00' 14.0]
#  ['5.00' 14.0]
#  ['2.00' 5.0]
#  ['5.00' 9.0]
#  ['5.00' 17.0]
#  ['5.00' 17.0]
#  ['5.00' 11.0]
#  ['1.00' 6.0]
#  ['5.00' 20.0]
#  ['5.00' 5.0]
#  ['4.00' 14.0]
#  ['4.00' 17.0]
#  ['5.00' 10.0]
#  ['5.00' 8.0]
#  ['5.00' 6.0]
#  ['5.00' 14.0]
#  ['5.00' 6.0]
#  ['5.00' 11.0]
#  ['5.00' 20.0]
#  ['5.00' 14.0]
#  ['5.00' 20.0]
#  ['4.00' 17.0]
#  ['5.00' 15.0]
#  ['5.00' 9.0]
#  ['5.00' 7.0]
#  ['5.00' 8.0]
#  ['5.00' 4.0]
#  ['5.00' 10.0]
#  ['5.00' 20.0]
#  ['5.00' 14.0]
#  ['4.00' 5.0]
#  ['5.00' 18.0]
#  ['5.00' 4.0]
#  ['5.00' 20.0]
#  ['5.00' 12.0]
#  ['5.00' 11.0]
#  ['2.00' 11.0]
#  ['5.00' 20.0]
#  ['1.00' 12.0]]
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

dataframe = pd.read_csv(r"/Users/huongnguyen/Downloads/use.csv")
points=dataframe[:39] 
points.F_APS=pd.to_numeric

sns.pairplot(points)

# %%
dataframe = pd.read_csv(r"/Users/huongnguyen/Downloads/use.csv")
points=dataframe[:39]
points.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
X = points.iloc[:, 0:39]
y = points.iloc[:, 0:39]

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y = y.apply(le.fit_transform)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.50)

print(len(X_train))
# Out:
# 19

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train)

X_train.describe()
# Out:
#                   0             1
# count  1.900000e+01  1.900000e+01
# mean   1.752984e-16  1.519253e-16
# std    1.027402e+00  1.027402e+00
# min   -2.754121e+00 -1.387121e+00
# 25%    1.075829e-01 -9.419300e-01
# 50%    5.163978e-01 -1.405866e-01
# 75%    5.163978e-01  7.497950e-01
# max    5.163978e-01  1.462100e+00

# %%
print(X.shape)
print(y.shape)
# Out:
# (39, 2)
# (39, 2)

# %%
import pandas as pd

points = points[['Freq._use','F_APS']]

# %%
#Splitting the dataset
from sklearn.model_selection import train_test_split
training_set, validation_set = train_test_split(points, test_size = 0.2, random_state = 21)

# %%
X_train = training_set.iloc[:,0:-1].values
Y_train = training_set.iloc[:,-1].values
X_val = validation_set.iloc[:,0:-1].values
y_val = validation_set.iloc[:,-1].values

# %%
def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements
print (accuracy)
# Out:
# <function accuracy at 0x7ff0a813f670>
